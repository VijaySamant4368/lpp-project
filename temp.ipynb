# %%
import osmnx as ox
import networkx as nx
import pandas as pd

place_name = "Chandigarh, India"
G = ox.graph_from_place(place_name, network_type="drive", simplify=True)
G = ox.add_edge_speeds(G)
G = ox.add_edge_travel_times(G)
gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)
print("--- Edges GeoDataFrame Head (Road Segments) ---")
print(gdf_edges[['osmid', 'length', 'travel_time', 'highway', 'oneway']].head())
ox.save_graphml(G, filepath="chandigarh_road_network.graphml")
print("\n--- Data Acquisition Complete ---")
print(f"Number of Nodes (Intersections): {len(G.nodes)}")
print(f"Number of Edges (Road Segments): {len(G.edges)}")
print("Graph data saved to 'new_delhi_road_network.graphml'")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import pandas as pd
#       5 place_name = "Chandigarh, India"
# ----> 6 G = ox.graph_from_place(place_name, network_type="drive", simplify=True)
#       7 G = ox.add_edge_speeds(G)
#       8 G = ox.add_edge_travel_times(G)
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\graph.py:395, in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, which_result, custom_filter)
#     392 utils.log(msg, level=lg.INFO)
#     394 # create graph using this polygon(s) geometry
# --> 395 G = graph_from_polygon(
#     396     polygon,
#     397     network_type=network_type,
#     398     simplify=simplify,
#     399     retain_all=retain_all,
#     400     truncate_by_edge=truncate_by_edge,
#     401     custom_filter=custom_filter,
#     402 )
#     404 msg = f"graph_from_place returned graph with {len(G):,} nodes and {len(G.edges):,} edges"
#     405 utils.log(msg, level=lg.INFO)
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\graph.py:501, in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, custom_filter)
#     495 G_buff = _create_graph(response_jsons, bidirectional)
#     497 # truncate buffered graph to the buffered polygon and retain_all for
#     498 # now. needed because overpass returns entire ways that also include
#     499 # nodes outside the poly if the way (that is, a way with a single OSM
#     500 # ID) has a node inside the poly at some point.
# --> 501 G_buff = truncate.truncate_graph_polygon(G_buff, poly_buff, truncate_by_edge=truncate_by_edge)
#     503 # keep only the largest weakly connected component if retain_all is False
#     504 if not retain_all:
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\truncate.py:127, in truncate_graph_polygon(G, polygon, truncate_by_edge)
#     124 utils.log(msg, level=lg.INFO)
#     126 # first identify all nodes whose point geometries lie within the polygon
# --> 127 gs_nodes = convert.graph_to_gdfs(G, edges=False)["geometry"]
#     128 to_keep = utils_geo._intersect_index_quadrats(gs_nodes, polygon)
#     130 if len(to_keep) == 0:
#     131     # no graph nodes within the polygon: can't create a graph from that
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\convert.py:158, in graph_to_gdfs(G, nodes, edges, node_geometry, fill_edge_geometry)
#     155 if node_geometry:
#     156     # convert node x/y attributes to Points for geometry column
#     157     node_geoms = (Point(d["x"], d["y"]) for d in data)
# --> 158     gdf_nodes = gpd.GeoDataFrame(data, index=uvk, crs=crs, geometry=list(node_geoms))
#     159 else:
#     160     gdf_nodes = gpd.GeoDataFrame(data, index=uvk)
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\convert.py:157, in <genexpr>(.0)
#     153 uvk, data = zip(*G.nodes(data=True))
#     155 if node_geometry:
#     156     # convert node x/y attributes to Points for geometry column
# --> 157     node_geoms = (Point(d["x"], d["y"]) for d in data)
#     158     gdf_nodes = gpd.GeoDataFrame(data, index=uvk, crs=crs, geometry=list(node_geoms))
#     159 else:
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\shapely\geometry\point.py:81, in Point.__new__(self, *args)
#      79 if not np.issubdtype(coords.dtype, np.number):
#      80     coords = [float(c) for c in coords]
# ---> 81 geom = shapely.points(coords)
#      82 if not isinstance(geom, Point):
#      83     raise ValueError("Invalid values passed to Point constructor")
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\shapely\decorators.py:173, in deprecate_positional.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @wraps(func)
#     172 def wrapper(*args, **kwargs):
# --> 173     result = func(*args, **kwargs)
#     175     n = len(args)
#     176     if n > warn_from:
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\shapely\decorators.py:88, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      86     for arr in array_args:
#      87         arr.flags.writeable = False
# ---> 88     return func(*args, **kwargs)
#      89 finally:
#      90     for arr, old_flag in zip(array_args, old_flags):
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\shapely\creation.py:124, in points(coords, y, z, indices, handle_nan, out, **kwargs)
#     122     handle_nan = HandleNaN.get_value(handle_nan)
#     123 if indices is None:
# --> 124     return lib.points(coords, np.intc(handle_nan), out=out, **kwargs)
#     125 else:
#     126     return simple_geometries_1d(
#     127         coords, indices, GeometryType.POINT, handle_nan=handle_nan, out=out
#     128     )
#
# KeyboardInterrupt:

# %%
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt

# Use exact coordinates instead of string (more reliable)
center_point = (23.35, 80.40)  # (lat, lon)

# 1775 km radius — this covers almost entire mainland India
G = ox.graph_from_point(
    center_point,
    dist=1_800_000,           # slightly larger buffer to be safe
    dist_type="bbox",
    network_type="drive",
    simplify=True,
    retain_all=False,
    truncate_by_edge=True
)

print(f"Full graph: {G.number_of_nodes():,} nodes, {G.number_of_edges():,} edges")

# Keep only primary, secondary, and tertiary (this is what real "nice" routes use)
desired_types = {"primary", "primary_link", "secondary", "secondary_link", "tertiary", "tertiary_link"}

# Also optionally keep trunk/trunk_link if you want a bit more connectivity
# desired_types.update({"trunk", "trunk_link"})

edges_to_remove = []
for u, v, k, data in G.edges(keys=True, data=True):
    hw = data.get("highway")
    if hw is None:
        edges_to_remove.append((u, v, k))
        continue
    hw_list = hw if isinstance(hw, list) else [hw]
    if not any(t in desired_types for t in hw_list):
        edges_to_remove.append((u, v, k))

G_filtered = G.copy()
G_filtered.remove_edges_from(edges_to_remove)

# Remove isolated nodes + disconnected components that are too small (noise)
G_filtered = ox.utils_graph.remove_isolated_nodes(G_filtered)
G_filtered = ox.get_largest_component(G_filtered, strongly=False)

print(f"Filtered graph: {G_filtered.number_of_nodes():,} nodes, {G_filtered.number_of_edges():,} edges")

# Plotting
fig, ax = ox.plot_graph(
    G_filtered,
    figsize=(16, 16),
    bgcolor="#ffffff",
    node_size=0,               # hide nodes for cleaner look
    edge_color="#d43838",      # nice red
    edge_linewidth=0.8,
    show=False,
    close=False
)

# Add a star at the center
ax.scatter(80.40, 23.35, c='yellow', s=400, marker='*', edgecolors='black', linewidth=1.5, zorder=5, label="Center of Mainland India")
ax.legend(loc="upper right", fontsize=14)

plt.title("Reachable India on Primary + Secondary + Tertiary Roads\n"
          "within ~1775 km of Geographic Center (Karaundi, Madhya Pradesh)", 
          fontsize=18, pad=20)

plt.tight_layout()
plt.show()

# Save for later use in your ILP
ox.save_graphml(G_filtered, filepath="india_mainland_primary_secondary_tertiary.graphml")
print("Saved: india_mainland_primary_secondary_tertiary.graphml")
# Out:
# c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\_overpass.py:271: UserWarning: This area is 5,175 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 9
#       6 center_point = (23.35, 80.40)  # (lat, lon)
#       8 # 1775 km radius — this covers almost entire mainland India
# ----> 9 G = ox.graph_from_point(
#      10     center_point,
#      11     dist=1_800_000,           # slightly larger buffer to be safe
#      12     dist_type="bbox",
#      13     network_type="drive",
#      14     simplify=True,
#      15     retain_all=False,
#      16     truncate_by_edge=True
#      17 )
#      19 print(f"Full graph: {G.number_of_nodes():,} nodes, {G.number_of_edges():,} edges")
#      21 # Keep only primary, secondary, and tertiary (this is what real "nice" routes use)
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\graph.py:200, in graph_from_point(center_point, dist, dist_type, network_type, simplify, retain_all, truncate_by_edge, custom_filter)
#     197 bbox = utils_geo.bbox_from_point(center_point, dist)
#     199 # create a graph from the bounding box
# --> 200 G = graph_from_bbox(
#     201     bbox,
#     202     network_type=network_type,
#     203     simplify=simplify,
#     204     retain_all=retain_all,
#     205     truncate_by_edge=truncate_by_edge,
#     206     custom_filter=custom_filter,
#     207 )
#     209 if dist_type == "network":
#     210     # find node nearest to center then truncate graph by dist from it
#     211     node = distance.nearest_nodes(G, X=center_point[1], Y=center_point[0])
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\graph.py:105, in graph_from_bbox(bbox, network_type, simplify, retain_all, truncate_by_edge, custom_filter)
#     102 polygon = utils_geo.bbox_to_poly(bbox)
#     104 # create graph using this polygon geometry
# --> 105 G = graph_from_polygon(
#     106     polygon,
#     107     network_type=network_type,
#     108     simplify=simplify,
#     109     retain_all=retain_all,
#     110     truncate_by_edge=truncate_by_edge,
#     111     custom_filter=custom_filter,
#     112 )
#     114 msg = f"graph_from_bbox returned graph with {len(G):,} nodes and {len(G.edges):,} edges"
#     115 utils.log(msg, level=lg.INFO)
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\graph.py:495, in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, custom_filter)
#     493 # create buffered graph from the downloaded data
#     494 bidirectional = network_type in settings.bidirectional_network_types
# --> 495 G_buff = _create_graph(response_jsons, bidirectional)
#     497 # truncate buffered graph to the buffered polygon and retain_all for
#     498 # now. needed because overpass returns entire ways that also include
#     499 # nodes outside the poly if the way (that is, a way with a single OSM
#     500 # ID) has a node inside the poly at some point.
#     501 G_buff = truncate.truncate_graph_polygon(G_buff, poly_buff, truncate_by_edge=truncate_by_edge)
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\graph.py:624, in _create_graph(response_jsons, bidirectional)
#     620 # consume response_jsons generator to download data from server. if
#     621 # cache_only_mode, just consume response_jsons then continue next loop.
#     622 # otherwise, extract nodes and paths from the downloaded OSM data.
#     623 response_count = 0
# --> 624 for response_json in response_jsons:
#     625     response_count += 1
#     626     if not settings.cache_only_mode:
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\_overpass.py:402, in _download_overpass_network(polygon, network_type, custom_filter)
#     400 for way_filter in way_filters:
#     401     query_str = f"{overpass_settings};(way{way_filter}(poly:{polygon_coord_str!r});>;);out;"
# --> 402     yield _overpass_request(OrderedDict(data=query_str))
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\_overpass.py:492, in _overpass_request(data)
#     490     msg = "Overpass API did not return a dict of results."
#     491     raise InsufficientResponseError(msg)
# --> 492 _http._save_to_cache(prepared_url, response_json, response.ok)
#     493 return response_json
#
# File c:\Users\vijay\Desktop\LPP\project\venv\lib\site-packages\osmnx\_http.py:63, in _save_to_cache(url, response_json, ok)
#      61 cache_filepath = _resolve_cache_filepath(url)
#      62 cache_filepath.parent.mkdir(parents=True, exist_ok=True)
# ---> 63 cache_filepath.write_text(json.dumps(response_json), encoding="utf-8")
#      64 msg = f"Saved response to cache file {str(cache_filepath)!r}"
#      65 utils.log(msg, level=lg.INFO)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pathlib.py:1153, in Path.write_text(self, data, encoding, errors, newline)
#    1151 encoding = io.text_encoding(encoding)
#    1152 with self.open(mode='w', encoding=encoding, errors=errors, newline=newline) as f:
# -> 1153     return f.write(data)
#
# OSError: [Errno 28] No space left on device

# %%
# Out:
# Coordinates: 12.9767936 77.590082

# %%
list(G_subset.edges(data=True))[:5]
# Out:
# [(30037235,
#   2197652486,
#   {'osmid': 209562047,
#    'highway': 'secondary',
#    'name': 'Langs Garden Road',
#    'oneway': True,
#    'reversed': False,
#    'length': np.float64(12.498709171778236)}),
#  (30037235,
#   254497449,
#   {'osmid': 1149875531,
#    'highway': 'primary',
#    'lanes': '2',
#    'name': 'EVR Periyar Salai',
#    'oneway': True,
#    'ref': 'SHU86',
#    'reversed': False,
#    'length': np.float64(191.83556099863466),
#    'geometry': <LINESTRING (80.265 13.081, 80.265 13.081, 80.267 13.081)>}),
#  (30037236,
#   304918752,
#   {'osmid': 27768980,
#    'highway': 'tertiary',
#    'name': 'EVK Sampath Salai',
#    'oneway': False,
#    'reversed': True,
#    'length': np.float64(12.45644078833209)}),
#  (30037236,
#   254497666,
#   {'osmid': 237621838,
#    'highway': 'primary',
#    'name': 'EVR Periyar Salai',
#    'oneway': True,
#    'ref': 'SHU86',
#    'reversed': False,
#    'length': np.float64(131.8217124476246)}),
#  (30037236,
#   254491154,
#   {'osmid': 27768980,
#    'highway': 'tertiary',
#    'name': 'EVK Sampath Salai',
#    'oneway': False,
#    'reversed': False,
#    'length': np.float64(305.69059719465065),
#    'geometry': <LINESTRING (80.263 13.08, 80.263 13.081, 80.263 13.081, 80.263 13.081, 80.2...>})]

# %%
ls="uytdfy"
# %ls
# Out:
#  Volume in drive C is ACER
#  Volume Serial Number is 6042-7170
#
#  Directory of c:\Users\vijay\Desktop\LPP\project
#
# 24-11-2025  14:15    <DIR>          .
# 19-11-2025  23:12    <DIR>          ..
# 18-11-2025  10:31    <DIR>          cache
# 24-11-2025  14:13        12,958,594 new_delhi_road_network.graphml
# 24-11-2025  14:16           757,742 temp.ipynb
# 24-11-2025  14:15         1,341,569 two.ipynb
# 18-11-2025  10:25    <DIR>          venv
#                3 File(s)     15,057,905 bytes
#                4 Dir(s)  25,807,339,520 bytes free
